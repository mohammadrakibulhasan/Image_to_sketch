# %%
# !pip install ImagetoSketch
# Out:
# Requirement already satisfied: ImagetoSketch in d:\anaconda\lib\site-packages (0.1.0)

# %%
from ImagetoSketch import *

# %%
ImagetoSketch(r'C:\Users\rakib\OneDrive\GitHub\Image_to_sketch\src\images\demo_2.png')
# Out:
# Original Dimensions :  (859, 840, 3)
